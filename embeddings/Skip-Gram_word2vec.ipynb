# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:17, 1.78MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

# %%
word_count = Counter(int_words)

# %%
prob_dict = {}
t = 1e-5
for wd, cnt in word_count.items():
    prob_dict[wd] = 1 - np.sqrt(t/(cnt/len(int_words)))

# %%
## Your code here

train_words = []# The final subsampled word list

for wd in int_words:
    if np.random.random() > prob_dict[wd]:
        train_words.append(wd)

# %%
len(train_words)
# Out:
# 4628396

# %%
len(int_words)
# Out:
# 16680599

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    window = np.random.choice(range(1, window_size+1))
    
    if idx - window > 0:
        
    
        return list(set(words[idx-window:idx] + words[idx+1:idx+1+window]))
    else:
        return list(set(words[0:idx] + words[idx+1:idx+1+window]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),minval=-1, maxval=1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding),stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7499 0.3769 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7111 0.3635 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6281 0.3620 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6851 0.3690 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6302 0.3690 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6510 0.3705 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6724 0.3717 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6811 0.3744 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5521 0.3739 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5174 0.3770 sec/batch
# Nearest to most: bfi, silkworth, curiae, twitch, enjambment, vaporized, raster, chamber,
# Nearest to has: crease, bali, pervez, herbst, ethical, cruised, icrm, tro,
# Nearest to american: abgar, alcan, tou, grotesque, concourse, corporal, iodides, connolly,
# Nearest to its: vanadium, furrow, collapses, palisades, schwerner, reckoning, crow, agathocles,
# Nearest to called: musei, comico, forbade, slit, aurochs, transformers, henry, scottish,
# Nearest to d: shop, mri, pasteur, pussy, pdpa, eases, mrna, timestamping,
# Nearest to his: precisely, chatting, scroll, aliases, resigned, attitude, ren, distinctions,
# Nearest to at: chechen, step, metheny, discontinuation, carillon, chancellorsville, evolutionism, bindi,
# Nearest to dr: supersessionism, dis, wakko, miho, odo, veterans, marcantonio, overheat,
# Nearest to proposed: crumpled, tuning, invaluable, kamon, maius, humps, boardwalk, tl,
# Nearest to alternative: correlatives, cholesteric, toile, milkman, buchanan, estudios, liouville, encephalopathy,
# Nearest to account: relinquished, instinctive, cao, limiting, guilds, widened, cartographic, unlawfully,
# Nearest to universe: maharaja, abdallah, leyla, diagrams, herz, chardin, krakow, bloat,
# Nearest to mainly: indie, hermetic, macron, dictum, boney, gabby, admissions, jaian,
# Nearest to know: tehran, petrified, brentwood, oedipus, submachine, politecnico, vents, latin,
# Nearest to nobel: minimi, tad, jens, soak, mutilation, reservoirs, eastward, cone,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5250 0.3901 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4252 0.3751 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4092 0.3772 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3465 0.3762 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2587 0.3879 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2271 0.3764 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1680 0.3760 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1176 0.3776 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0405 0.3815 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0402 0.4077 sec/batch
# Nearest to most: chamber, curiae, silkworth, al, transportation, bfi, raster, early,
# Nearest to has: crease, ethical, place, cruised, jet, bali, aqua, exhaustion,
# Nearest to american: alcan, tou, grotesque, gwen, tourism, abgar, selected, mani,
# Nearest to its: collapses, spend, we, vanadium, furrow, reckoning, reprinted, crow,
# Nearest to called: forbade, scottish, comico, henry, slit, musei, covered, mediums,
# Nearest to d: shop, pasteur, pussy, mri, eases, mrna, timings, nudie,
# Nearest to his: precisely, scroll, distinctions, chatting, attitude, aliases, resigned, destructor,
# Nearest to at: step, chechen, subject, feature, metheny, device, always, columbia,
# Nearest to dr: dis, supersessionism, veterans, picnic, guides, odo, cabinet, ho,
# Nearest to proposed: tuning, invaluable, crumpled, third, association, mentally, debut, kamon,
# Nearest to alternative: cholesteric, buchanan, correlatives, convince, encephalopathy, liouville, nylon, revelation,
# Nearest to account: relinquished, limiting, instinctive, widened, guilds, cartographic, davidian, cao,
# Nearest to universe: diagrams, maharaja, abdallah, herz, press, krakow, leyla, witnessed,
# Nearest to mainly: indie, macron, admissions, gabby, robots, crystals, dictum, hermetic,
# Nearest to know: tehran, petrified, oedipus, latin, brentwood, gardening, submachine, elsewhere,
# Nearest to nobel: minimi, tad, mutilation, eastward, soak, tarrant, reservoirs, cone,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9854 0.4292 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9732 0.4040 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9414 0.3783 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9316 0.3770 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8775 0.3767 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8968 0.3840 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8580 0.3758 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8561 0.3764 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8314 0.3775 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8369 0.3768 sec/batch
# Nearest to most: raster, chamber, curiae, silkworth, bfi, al, transportation, historicity,
# Nearest to has: crease, bali, ethical, exhaustion, place, aqua, cruised, scanning,
# Nearest to american: alcan, grotesque, tourism, tou, unfounded, gwen, mani, ee,
# Nearest to its: collapses, vanadium, furrow, spend, reckoning, clinton, crow, matured,
# Nearest to called: forbade, slit, musei, comico, scottish, henry, amadeus, transformers,
# Nearest to d: shop, pasteur, pussy, eases, mri, imbolc, sim, mrna,
# Nearest to his: precisely, scroll, ren, resigned, chatting, kilograms, cabinet, crucified,
# Nearest to at: chechen, step, discretion, subject, metheny, feature, device, microscopic,
# Nearest to dr: dis, supersessionism, veterans, picnic, cabinet, guides, odo, ho,
# Nearest to proposed: crumpled, tuning, invaluable, mentally, third, association, debut, apollonius,
# Nearest to alternative: buchanan, convince, cholesteric, correlatives, nylon, revelation, encephalopathy, liouville,
# Nearest to account: relinquished, instinctive, widened, cartographic, guilds, limiting, cao, conclude,
# Nearest to universe: diagrams, maharaja, herz, abdallah, bloat, krakow, leyla, witnessed,
# Nearest to mainly: indie, macron, dictum, admissions, crystals, hermetic, robots, gabby,
# Nearest to know: submachine, petrified, oedipus, tehran, vents, brentwood, gardening, politecnico,
# Nearest to nobel: tad, mutilation, tarrant, shopping, reservoirs, eastward, surfaces, minimi,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8345 0.3807 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8101 0.3799 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7472 0.3813 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7595 0.3745 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7699 0.3786 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7662 0.3747 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7210 0.3768 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7796 0.3848 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7428 0.3785 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6814 0.3780 sec/batch
# Nearest to most: raster, silkworth, curiae, twitch, bfi, chamber, al, decompose,
# Nearest to has: bali, crease, exhaustion, cruised, pervez, breech, scanning, aqua,
# Nearest to american: alcan, grotesque, gwen, maurice, tou, eight, unfounded, tourism,
# Nearest to its: collapses, reckoning, vanadium, furrow, clinton, spend, matured, palisades,
# Nearest to called: slit, musei, forbade, comico, transformers, scottish, subdivided, parabola,
# Nearest to d: shop, pussy, pasteur, eases, malignancies, sim, timestamping, mri,
# Nearest to his: scroll, precisely, ren, resigned, disused, chatting, aliases, kilograms,
# Nearest to at: chechen, step, metheny, zachary, discretion, fictionalized, chancellorsville, surrender,
# Nearest to dr: supersessionism, dis, veterans, cabinet, picnic, odo, ho, wharton,
# Nearest to proposed: crumpled, tuning, invaluable, boardwalk, mentally, maius, collaboratively, kamon,
# Nearest to alternative: buchanan, cholesteric, convince, correlatives, nylon, encephalopathy, seaman, liouville,
# Nearest to account: relinquished, instinctive, widened, cao, cartographic, guilds, ararat, davidian,
# Nearest to universe: diagrams, maharaja, leyla, krakow, abdallah, chaim, russell, herz,
# Nearest to mainly: indie, macron, dictum, admissions, hermetic, crystals, requisite, nina,
# Nearest to know: submachine, tehran, petrified, oedipus, brentwood, vents, cker, px,
# Nearest to nobel: tad, soak, xico, tarrant, reservoirs, adonis, mutilation, eastward,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6933 0.3777 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6970 0.3755 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6513 0.3815 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6455 0.3711 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6602 0.3748 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6617 0.3788 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6074 0.2677 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5502 0.3789 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4944 0.3763 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5136 0.3739 sec/batch
# Nearest to most: silkworth, raster, twitch, curiae, carlist, deliverance, decompose, chamber,
# Nearest to has: bali, cruised, crease, pervez, exhaustion, breech, spinrad, herbst,
# Nearest to american: alcan, maurice, gwen, grotesque, abgar, tou, gilbert, eight,
# Nearest to its: reckoning, vanadium, furrow, collapses, matured, palisades, faring, spend,
# Nearest to called: slit, musei, forbade, comico, parabola, transformers, mediums, sapiens,
# Nearest to d: pianist, shop, pussy, sim, eases, b, pasteur, malignancies,
# Nearest to his: scroll, precisely, kilograms, ren, cabinet, against, resigned, despair,
# Nearest to at: chechen, metheny, chancellorsville, step, intersystems, surrender, anyhow, feature,
# Nearest to dr: supersessionism, dis, cabinet, picnic, veterans, odo, roberts, ho,
# Nearest to proposed: tuning, crumpled, maius, boardwalk, invaluable, collaboratively, apollonius, mentally,
# Nearest to alternative: cholesteric, buchanan, encephalopathy, correlatives, nylon, revelation, liouville, seaman,
# Nearest to account: instinctive, relinquished, widened, cao, cartographic, guilds, ararat, pfa,
# Nearest to universe: diagrams, krakow, maharaja, chaim, leyla, bake, abdallah, physiocrats,
# Nearest to mainly: indie, dictum, macron, admissions, hermetic, crystals, laboratories, robots,
# Nearest to know: submachine, oedipus, brentwood, petrified, tehran, physical, gardening, vents,
# Nearest to nobel: prize, scholar, tad, xico, jens, isbn, american, footballer,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4935 0.3703 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4506 0.3678 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4277 0.3741 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4966 0.3638 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4555 0.3632 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4726 0.3720 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4472 0.3645 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3618 0.3664 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4221 0.3652 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4039 0.3722 sec/batch
# Nearest to most: silkworth, raster, twitch, carlist, vaporized, transportation, chamber, gatsby,
# Nearest to has: bali, crease, breech, pervez, cruised, spinrad, sector, exhaustion,
# Nearest to american: alcan, maurice, grotesque, gwen, abgar, tou, connolly, gilbert,
# Nearest to its: vanadium, reckoning, furrow, faring, matured, substituent, spend, collapses,
# Nearest to called: slit, musei, mediums, parabola, comico, forbade, clockwork, sapiens,
# Nearest to d: shop, pasteur, pussy, sim, pianist, malignancies, eases, nibelungenlied,
# Nearest to his: scroll, precisely, despair, attitude, against, kilograms, resigned, disused,
# Nearest to at: chechen, mendelians, zachary, feature, chancellorsville, surrender, takes, intersystems,
# Nearest to dr: supersessionism, dis, odo, cabinet, picnic, veterans, armadillo, wharton,
# Nearest to proposed: tuning, collaboratively, maius, crumpled, boardwalk, apollonius, tl, invaluable,
# Nearest to alternative: cholesteric, buchanan, correlatives, encephalopathy, nylon, liouville, toile, milkman,
# Nearest to account: instinctive, relinquished, widened, cao, cartographic, ararat, hedwig, geoffrey,
# Nearest to universe: diagrams, krakow, chaim, bake, physiocrats, sledge, maharaja, leyla,
# Nearest to mainly: dictum, indie, admissions, macron, crystals, hermetic, robots, laboratories,
# Nearest to know: submachine, brentwood, petrified, oedipus, gardening, physical, cker, drafts,
# Nearest to nobel: prize, scholar, jens, tad, xico, librettist, tarrant, financier,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4276 0.3686 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4288 0.3649 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4635 0.3684 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3884 0.3620 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4223 0.3666 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4323 0.3659 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3544 0.3697 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3704 0.3654 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4007 0.3698 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3521 0.3648 sec/batch
# Nearest to most: twitch, raster, silkworth, vaporized, wherefore, carlist, bfi, chamber,
# Nearest to has: bali, breech, pervez, crease, cruised, spinrad, poisonings, herbst,
# Nearest to american: maurice, alcan, connolly, grotesque, abgar, tou, gwen, gilbert,
# Nearest to its: reckoning, vanadium, faring, furrow, palisades, matured, substituent, blasted,
# Nearest to called: slit, musei, scottish, parabola, comico, forbade, sapiens, clockwork,
# Nearest to d: pasteur, malignancies, shop, sim, eases, nibelungenlied, pussy, pianist,
# Nearest to his: precisely, despair, scroll, he, against, rob, explicated, attitude,
# Nearest to at: chechen, zachary, mendelians, surrender, laughs, intersystems, takes, metheny,
# Nearest to dr: supersessionism, picnic, odo, dis, concordes, roberts, marlene, millionaires,
# Nearest to proposed: boardwalk, tuning, maius, crumpled, collaboratively, invaluable, peculiarly, madama,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, buchanan, milkman, liouville, nylon, toile,
# Nearest to account: instinctive, widened, cao, relinquished, cartographic, perforce, ararat, uncompleted,
# Nearest to universe: diagrams, bake, chaim, physiocrats, maharaja, sledge, krakow, leyla,
# Nearest to mainly: dictum, macron, admissions, indie, crystals, diplomatique, hermetic, xie,
# Nearest to know: submachine, brentwood, petrified, oedipus, gentiles, gardening, drafts, cker,
# Nearest to nobel: prize, scholar, jens, financier, xico, librettist, tarrant, edith,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3628 0.3702 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3541 0.3838 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3474 0.3649 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3391 0.3663 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3826 0.3661 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3694 0.3670 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3968 0.3663 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3634 0.3639 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3224 0.3723 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3221 0.3634 sec/batch
# Nearest to most: raster, twitch, silkworth, transportation, carlist, wherefore, dutiful, vaporized,
# Nearest to has: bali, pervez, breech, spinrad, herbst, poisonings, the, applicants,
# Nearest to american: alcan, abgar, connolly, maurice, tou, gwen, tourism, grotesque,
# Nearest to its: vanadium, reckoning, substituent, faring, furrow, matured, palisades, blasted,
# Nearest to called: slit, scottish, comico, musei, sapiens, forbade, henry, parabola,
# Nearest to d: pasteur, malignancies, eases, sim, shop, nibelungenlied, m, pussy,
# Nearest to his: precisely, he, despair, resigned, scroll, accompany, explicated, ren,
# Nearest to at: mendelians, zachary, surrender, chechen, determinations, intersystems, takes, juneau,
# Nearest to dr: picnic, odo, supersessionism, miho, dis, marlene, concordes, millionaires,
# Nearest to proposed: boardwalk, maius, crumpled, tuning, collaboratively, invaluable, madama, mentally,
# Nearest to alternative: correlatives, cholesteric, encephalopathy, milkman, buchanan, gospel, liouville, bellori,
# Nearest to account: instinctive, widened, relinquished, cao, cartographic, perforce, ararat, geoffrey,
# Nearest to universe: diagrams, physiocrats, bake, chaim, herz, maharaja, sledge, bloat,
# Nearest to mainly: dictum, admissions, macron, indie, crystals, diplomatique, xie, incompetence,
# Nearest to know: submachine, oedipus, petrified, gardening, gentiles, brentwood, drafts, cker,
# Nearest to nobel: prize, jens, xico, tarrant, financier, librettist, scholar, edith,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3709 0.3782 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2918 0.3673 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3612 0.3729 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3522 0.3688 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3662 0.3838 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2829 0.3749 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2936 0.3652 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3082 0.3644 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1988 0.3740 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2867 0.3739 sec/batch
# Nearest to most: raster, twitch, carlist, dutiful, silkworth, wherefore, mayflower, transportation,
# Nearest to has: pervez, breech, bali, poisonings, spinrad, sector, herbst, applicants,
# Nearest to american: maurice, gwen, alcan, connolly, tou, abgar, gilbert, blackstone,
# Nearest to its: vanadium, substituent, faring, furrow, palisades, reckoning, matured, archtop,
# Nearest to called: slit, musei, scottish, comico, sapiens, forbade, henry, parabola,
# Nearest to d: pasteur, sim, pianist, physiologist, b, nibelungenlied, donna, malignancies,
# Nearest to his: precisely, he, resigned, scroll, despair, paced, had, accompany,
# Nearest to at: zachary, mendelians, surrender, chechen, juneau, intersystems, clutter, determinations,
# Nearest to dr: picnic, odo, supersessionism, dis, miho, millionaires, marlene, cabinet,
# Nearest to proposed: crumpled, boardwalk, maius, collaboratively, madama, invaluable, tuning, oratorios,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, milkman, bellori, buchanan, gospel, toile,
# Nearest to account: instinctive, widened, relinquished, cartographic, cao, geoffrey, perforce, ararat,
# Nearest to universe: diagrams, physiocrats, chaim, russell, bake, sledge, leyla, herz,
# Nearest to mainly: dictum, admissions, macron, crystals, indie, diplomatique, mica, incompetence,
# Nearest to know: submachine, oedipus, dubliners, cker, petrified, pricking, drafts, brentwood,
# Nearest to nobel: prize, jens, financier, xico, tarrant, librettist, edith, soak,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3091 0.3774 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3004 0.3678 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3166 0.1628 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2045 0.3775 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1785 0.3689 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1841 0.3686 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2106 0.3677 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1654 0.3930 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1869 0.3944 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1551 0.3761 sec/batch
# Nearest to most: twitch, raster, carlist, transportation, dutiful, silkworth, urbanized, mayflower,
# Nearest to has: poisonings, pervez, bali, giraldus, spinrad, breech, herbst, sector,
# Nearest to american: abgar, alcan, connolly, gwen, tou, maurice, blackstone, bruin,
# Nearest to its: vanadium, palisades, faring, reckoning, vcrs, substituent, matured, blasted,
# Nearest to called: slit, musei, scottish, clockwork, comico, sapiens, henry, forbade,
# Nearest to d: pasteur, sim, pussy, physiologist, pianist, donna, nibelungenlied, eases,
# Nearest to his: precisely, he, scroll, despair, had, paced, against, resigned,
# Nearest to at: surrender, zachary, mendelians, intersystems, determinations, chancellorsville, takes, clutter,
# Nearest to dr: odo, picnic, miho, supersessionism, dis, millionaires, marlene, cabinet,
# Nearest to proposed: maius, crumpled, boardwalk, collaboratively, madama, invaluable, oratorios, tuning,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, milkman, buchanan, bellori, toile, dodds,
# Nearest to account: instinctive, relinquished, geoffrey, cartographic, widened, cao, ararat, perforce,
# Nearest to universe: diagrams, chaim, physiocrats, bake, russell, wavefunction, loves, sledge,
# Nearest to mainly: dictum, admissions, macron, indie, diplomatique, xie, crystals, didactic,
# Nearest to know: submachine, oedipus, dubliners, drafts, pricking, petrified, gardening, cker,
# Nearest to nobel: prize, jens, librettist, financier, xico, tarrant, soak, minimi,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2101 0.3815 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1883 0.3734 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1931 0.3846 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0862 0.3731 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1493 0.3721 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1177 0.3715 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1566 0.3706 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1303 0.3728 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1832 0.3759 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1605 0.3704 sec/batch
# Nearest to most: twitch, raster, silkworth, vaporized, transportation, francophonie, urbanized, decompose,
# Nearest to has: poisonings, breech, pervez, spinrad, bali, giraldus, have, lovelock,
# Nearest to american: abgar, connolly, alcan, gwen, tou, maurice, bruin, tourism,
# Nearest to its: vanadium, vcrs, archtop, substituent, palisades, reckoning, faring, matured,
# Nearest to called: slit, scottish, musei, henry, clockwork, comico, parabola, forbade,
# Nearest to d: pasteur, sim, eases, malignancies, pussy, timestamping, nibelungenlied, imbolc,
# Nearest to his: precisely, he, explicated, scroll, paced, despair, accompany, had,
# Nearest to at: mendelians, zachary, surrender, determinations, laughs, clutter, chancellorsville, intersystems,
# Nearest to dr: picnic, odo, millionaires, miho, marlene, overheat, roberts, dis,
# Nearest to proposed: crumpled, maius, boardwalk, madama, collaboratively, invaluable, tuning, oratorios,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, milkman, buchanan, bellori, toile, dodds,
# Nearest to account: instinctive, geoffrey, cartographic, relinquished, widened, ararat, perforce, cao,
# Nearest to universe: diagrams, wavefunction, bake, loves, physiocrats, newton, constructible, herz,
# Nearest to mainly: dictum, macron, admissions, indie, crystals, diplomatique, xie, didactic,
# Nearest to know: submachine, dubliners, that, oedipus, drafts, petrified, swear, nicotine,
# Nearest to nobel: prize, jens, librettist, financier, xico, soak, tarrant, minimi,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1427 0.3780 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1635 0.3758 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1400 0.3711 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1114 0.3709 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1497 0.3747 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1425 0.3725 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1707 0.3724 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1174 0.3723 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1149 0.3742 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1474 0.3753 sec/batch
# Nearest to most: twitch, raster, carlist, heft, francophonie, basses, third, wherefore,
# Nearest to has: poisonings, the, have, pervez, breech, giraldus, sector, bali,
# Nearest to american: abgar, maurice, alcan, connolly, gwen, tou, bruin, blackstone,
# Nearest to its: vanadium, gaelic, substituent, archtop, vcrs, faring, palisades, schwerner,
# Nearest to called: slit, scottish, musei, comico, henry, clockwork, subdivided, kampuchean,
# Nearest to d: pasteur, sim, eases, nibelungenlied, malignancies, timestamping, bibliographer, pussy,
# Nearest to his: precisely, he, explicated, topologies, despair, accompany, scroll, resigned,
# Nearest to at: mendelians, zachary, clutter, surrender, determinations, leben, laughs, integral,
# Nearest to dr: picnic, odo, millionaires, roberts, overheat, miho, nss, studia,
# Nearest to proposed: crumpled, boardwalk, maius, collaboratively, marxist, madama, explain, oratorios,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, milkman, bellori, buchanan, toile, haystack,
# Nearest to account: instinctive, geoffrey, cartographic, relinquished, widened, ararat, perforce, cao,
# Nearest to universe: diagrams, loves, bake, civilization, wavefunction, physiocrats, stars, herz,
# Nearest to mainly: dictum, macron, admissions, indie, diplomatique, idiomatic, xie, crystals,
# Nearest to know: submachine, that, drafts, suggesting, oedipus, dubliners, nicotine, physical,
# Nearest to nobel: prize, jens, xico, tarrant, electrodynamics, roald, financier, librettist,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1833 0.3802 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1188 0.3807 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1518 0.3906 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1470 0.3715 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1148 0.3748 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1360 0.3741 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1396 0.3674 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1148 0.3754 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1912 0.3737 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2026 0.3745 sec/batch
# Nearest to most: twitch, raster, basses, francophonie, third, rathdown, carlist, dutiful,
# Nearest to has: poisonings, pervez, avraham, the, giraldus, spinrad, applicants, breech,
# Nearest to american: connolly, alcan, maurice, abgar, gwen, bruin, tou, curran,
# Nearest to its: vanadium, gaelic, faring, palisades, substituent, archtop, schwerner, reckoning,
# Nearest to called: slit, scottish, comico, musei, clockwork, henry, subdivided, kampuchean,
# Nearest to d: pasteur, bibliographer, pianist, nibelungenlied, sim, falkirk, corr, eases,
# Nearest to his: he, precisely, despair, had, topologies, paced, explicated, resigned,
# Nearest to at: zachary, mendelians, determinations, surrender, clutter, attended, laughs, leben,
# Nearest to dr: picnic, odo, millionaires, miho, roberts, overheat, studia, nss,
# Nearest to proposed: crumpled, boardwalk, maius, madama, collaboratively, marxist, explain, administratively,
# Nearest to alternative: cholesteric, correlatives, buchanan, milkman, bellori, haystack, encephalopathy, realizations,
# Nearest to account: instinctive, geoffrey, cartographic, relinquished, hedwig, ararat, widened, perforce,
# Nearest to universe: diagrams, loves, bake, stars, copernican, physiocrats, bolder, civilization,
# Nearest to mainly: macron, dictum, admissions, indie, idiomatic, protanomaly, diplomatique, crystals,
# Nearest to know: submachine, dubliners, don, drafts, that, suggesting, myself, oedipus,
# Nearest to nobel: prize, jens, roald, electrodynamics, physiology, financier, tarrant, winners,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1878 0.3750 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1261 0.3697 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0947 0.3704 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1342 0.3717 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0202 0.3725 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1250 0.3729 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1013 0.3733 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0915 0.3744 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1634 0.0621 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0823 0.4027 sec/batch
# Nearest to most: twitch, raster, third, basses, francophonie, in, rathdown, carlist,
# Nearest to has: poisonings, pervez, avraham, giraldus, applicants, herbst, spinrad, the,
# Nearest to american: abgar, alcan, connolly, maurice, gwen, bruin, tou, abilities,
# Nearest to its: vanadium, palisades, substituent, gaelic, faring, archtop, verde, phonemic,
# Nearest to called: slit, scottish, comico, musei, clockwork, subdivided, henry, vec,
# Nearest to d: pasteur, physiologist, bibliographer, pianist, nibelungenlied, emmett, sim, eases,
# Nearest to his: he, precisely, despair, topologies, accompany, paced, had, resigned,
# Nearest to at: mendelians, zachary, laughs, determinations, clutter, attended, unfortunately, leben,
# Nearest to dr: picnic, millionaires, odo, overheat, miho, roberts, wakko, nss,
# Nearest to proposed: crumpled, collaboratively, maius, explain, boardwalk, jeppesen, marxist, nkrumah,
# Nearest to alternative: cholesteric, correlatives, encephalopathy, bellori, milkman, realizations, buchanan, haystack,
# Nearest to account: instinctive, geoffrey, cartographic, relinquished, perforce, ararat, widened, cao,
# Nearest to universe: diagrams, loves, bake, civilization, physiocrats, stars, copernican, bolder,
# Nearest to mainly: macron, dictum, admissions, indie, crystals, protanomaly, idiomatic, mica,
# Nearest to know: submachine, dubliners, that, don, drafts, physical, myself, nicotine,
# Nearest to nobel: prize, jens, electrodynamics, physiology, financier, roald, winners, soak,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0458 0.3979 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0551 0.3774 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0386 0.3714 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0177 0.3687 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0388 0.3913 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0225 0.3961 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0529 0.3702 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0602 0.3675 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0924 0.3705 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9850 0.3675 sec/batch
# Nearest to most: twitch, raster, third, in, basses, densely, decompose, francophonie,
# Nearest to has: poisonings, giraldus, avraham, applicants, folger, pervez, lovelock, spinrad,
# Nearest to american: alcan, abgar, bruin, connolly, gwen, abilities, maurice, tou,
# Nearest to its: vanadium, faring, gaelic, substituent, palisades, exhaled, often, archtop,
# Nearest to called: slit, scottish, comico, clockwork, musei, henry, vec, subdivided,
# Nearest to d: pasteur, bibliographer, eases, nibelungenlied, malignancies, pussy, mri, sim,
# Nearest to his: he, precisely, accompany, paced, explicated, despair, resigned, had,
# Nearest to at: mendelians, zachary, unfortunately, laughs, leben, clutter, warheads, determinations,
# Nearest to dr: picnic, odo, millionaires, miho, overheat, wakko, haemophilus, nss,
# Nearest to proposed: explain, maius, crumpled, jeppesen, collaboratively, marxist, madama, boardwalk,
# Nearest to alternative: cholesteric, correlatives, bellori, encephalopathy, ovary, buchanan, realizations, dodds,
# Nearest to account: instinctive, geoffrey, cartographic, relinquished, hedwig, perforce, ararat, monsters,
# Nearest to universe: diagrams, stars, copernican, bake, loves, physiocrats, bolder, wavefunction,
# Nearest to mainly: macron, dictum, admissions, crystals, indie, protanomaly, idiomatic, laboratories,
# Nearest to know: submachine, dubliners, don, drafts, myself, px, credo, suggesting,
# Nearest to nobel: prize, jens, electrodynamics, roald, financier, winners, physiology, tarrant,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0023 0.3805 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9892 0.3667 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9798 0.3677 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0230 0.3684 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0604 0.3691 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0400 0.3689 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0231 0.3692 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0599 0.3694 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0349 0.3707 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0193 0.3683 sec/batch
# Nearest to most: twitch, in, third, raster, silkworth, basses, decompose, vaporized,
# Nearest to has: poisonings, giraldus, the, have, avraham, applicants, folger, pervez,
# Nearest to american: bruin, abgar, alcan, connolly, gwen, maurice, dictatorship, blackstone,
# Nearest to its: vanadium, gaelic, palisades, archtop, phonemic, substituent, exhaled, often,
# Nearest to called: slit, scottish, vec, clockwork, subdivided, comico, musei, henry,
# Nearest to d: pasteur, bibliographer, eases, nibelungenlied, malignancies, mri, pussy, sim,
# Nearest to his: he, precisely, explicated, accompany, topologies, knuckles, resigned, paced,
# Nearest to at: zachary, mendelians, leben, laughs, unfortunately, clutter, gre, exponential,
# Nearest to dr: picnic, millionaires, overheat, miho, wakko, nss, odo, haemophilus,
# Nearest to proposed: explain, jeppesen, crumpled, maius, factorize, collaboratively, marxist, madama,
# Nearest to alternative: cholesteric, correlatives, bellori, ovary, encephalopathy, milkman, buchanan, riso,
# Nearest to account: instinctive, geoffrey, cartographic, perforce, ararat, hedwig, relinquished, uncompleted,
# Nearest to universe: diagrams, stars, civilization, copernican, abdallah, bake, herz, physiocrats,
# Nearest to mainly: dictum, macron, admissions, idiomatic, indie, crystals, protanomaly, didactic,
# Nearest to know: submachine, dubliners, don, drafts, px, that, credo, myself,
# Nearest to nobel: prize, jens, electrodynamics, roald, financier, winners, tarrant, physiology,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0327 0.3755 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0773 0.3653 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0384 0.3704 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0226 0.3689 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0589 0.3624 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0005 0.3589 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0264 0.3620 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0555 0.3606 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0713 0.3625 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0221 0.3622 sec/batch
# Nearest to most: twitch, third, raster, basses, rathdown, silkworth, francophonie, carlist,
# Nearest to has: giraldus, poisonings, avraham, folger, have, applicants, pervez, orapa,
# Nearest to american: bruin, abgar, alcan, connolly, dictatorship, blackstone, training, gwen,
# Nearest to its: vanadium, gaelic, palisades, caricatured, phonemic, faring, schwerner, substituent,
# Nearest to called: slit, scottish, comico, subdivided, henry, reval, musei, clockwork,
# Nearest to d: pasteur, eases, bibliographer, mri, nibelungenlied, pussy, timestamping, malignancies,
# Nearest to his: he, precisely, resigned, accompany, knuckles, topologies, explicated, despair,
# Nearest to at: zachary, mendelians, leben, determinations, clutter, laughs, gre, unfortunately,
# Nearest to dr: picnic, miho, odo, millionaires, zy, roberts, overheat, wakko,
# Nearest to proposed: explain, crumpled, jeppesen, maius, boardwalk, marxist, nkrumah, milligan,
# Nearest to alternative: cholesteric, correlatives, bellori, ovary, amsterdam, buchanan, haystack, buckland,
# Nearest to account: instinctive, geoffrey, cartographic, perforce, ararat, hedwig, relinquished, uncompleted,
# Nearest to universe: diagrams, stars, abdallah, civilization, herz, copernican, bake, physiocrats,
# Nearest to mainly: macron, dictum, admissions, indie, crystals, protanomaly, idiomatic, didactic,
# Nearest to know: submachine, don, dubliners, px, credo, myself, drafts, nicotine,
# Nearest to nobel: prize, jens, electrodynamics, winners, roald, minimi, financier, tarrant,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0204 0.3638 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9944 0.3613 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9949 0.3594 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0311 0.3599 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0737 0.3612 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1333 0.3597 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1117 0.3576 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0281 0.3608 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9869 0.3608 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0301 0.3571 sec/batch
# Nearest to most: twitch, third, in, rathdown, raster, basses, heft, silkworth,
# Nearest to has: poisonings, the, folger, avraham, applicants, giraldus, pervez, have,
# Nearest to american: bruin, alcan, connolly, abgar, gwen, dictatorship, uel, maurice,
# Nearest to its: vanadium, gaelic, phonemic, substituent, archtop, caricatured, exhaled, often,
# Nearest to called: slit, scottish, comico, clockwork, vec, reval, subdivided, musei,
# Nearest to d: pasteur, bibliographer, pussy, falkirk, eases, nibelungenlied, mri, sim,
# Nearest to his: he, precisely, resigned, accompany, knuckles, topologies, spaten, brilliantly,
# Nearest to at: zachary, clutter, in, mendelians, determinations, gre, laughs, leben,
# Nearest to dr: picnic, odo, overheat, millionaires, miho, roberts, zy, wakko,
# Nearest to proposed: explain, crumpled, maius, jeppesen, boardwalk, gpo, nkrumah, milligan,
# Nearest to alternative: cholesteric, correlatives, amsterdam, bellori, buchanan, ovary, realizations, haystack,
# Nearest to account: geoffrey, instinctive, cartographic, perforce, ararat, hedwig, uncompleted, relinquished,
# Nearest to universe: diagrams, abdallah, stars, copernican, civilization, handcuffs, herz, constructible,
# Nearest to mainly: macron, dictum, admissions, indie, protanomaly, crystals, idiomatic, laboratories,
# Nearest to know: don, submachine, dubliners, px, myself, nicotine, drafts, credo,
# Nearest to nobel: prize, jens, winners, electrodynamics, roald, financier, tarrant, minimi,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9615 0.3666 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0110 0.3613 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9842 0.3606 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0315 0.3604 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0384 0.3585 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9964 0.3173 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9561 0.3608 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9166 0.3602 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9963 0.3620 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9436 0.3621 sec/batch
# Nearest to most: third, in, twitch, rathdown, raster, basses, carlist, francophonie,
# Nearest to has: poisonings, giraldus, applicants, folger, avraham, have, kult, pluralistic,
# Nearest to american: bruin, alcan, connolly, abgar, dictatorship, uel, rota, gwen,
# Nearest to its: gaelic, vanadium, palisades, often, archtop, caricatured, phonemic, substituent,
# Nearest to called: slit, scottish, comico, clockwork, vec, wied, henry, musei,
# Nearest to d: pasteur, bibliographer, ric, falkirk, pussy, pianist, imbolc, eases,
# Nearest to his: he, precisely, resigned, accompany, topologies, brilliantly, took, knuckles,
# Nearest to at: zachary, in, unfortunately, gre, clutter, mendelians, leben, determinations,
# Nearest to dr: picnic, overheat, odo, miho, haemophilus, millionaires, roberts, zy,
# Nearest to proposed: explain, jeppesen, crumpled, maius, gpo, boardwalk, milligan, nkrumah,
# Nearest to alternative: cholesteric, correlatives, bellori, ovary, amsterdam, riso, buchanan, realizations,
# Nearest to account: instinctive, geoffrey, cartographic, perforce, hedwig, prefaces, ararat, ministership,
# Nearest to universe: diagrams, abdallah, herz, civilization, copernican, handcuffs, stars, mika,
# Nearest to mainly: dictum, macron, admissions, indie, crystals, protanomaly, idiomatic, layouts,
# Nearest to know: don, submachine, dubliners, px, myself, drafts, greenwald, nicotine,
# Nearest to nobel: prize, jens, winners, roald, electrodynamics, financier, minimi, tarrant,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9420 0.3638 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9297 0.3600 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9859 0.3606 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9850 0.3590 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9677 0.3587 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0013 0.3606 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8579 0.3600 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9023 0.3618 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8908 0.3604 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9294 0.3596 sec/batch
# Nearest to most: in, twitch, third, rulebooks, raster, basses, francophonie, aural,
# Nearest to has: poisonings, have, giraldus, the, cups, applicants, folger, avraham,
# Nearest to american: bruin, alcan, connolly, abgar, dictatorship, uel, gwen, rota,
# Nearest to its: vanadium, gaelic, phonemic, archtop, caricatured, substituent, palisades, exhaled,
# Nearest to called: slit, scottish, clockwork, comico, henry, described, subdivided, vec,
# Nearest to d: pasteur, mri, eases, pussy, bibliographer, falkirk, imbolc, nibelungenlied,
# Nearest to his: he, precisely, resigned, topologies, accompany, knuckles, explicated, tenure,
# Nearest to at: in, zachary, unfortunately, gre, clutter, mendelians, determinations, courtyards,
# Nearest to dr: picnic, haemophilus, odo, overheat, endowment, roberts, millionaires, nss,
# Nearest to proposed: explain, jeppesen, crumpled, maius, gpo, boardwalk, milligan, nkrumah,
# Nearest to alternative: cholesteric, bellori, amsterdam, riso, correlatives, ovary, buchanan, realizations,
# Nearest to account: geoffrey, instinctive, cartographic, perforce, hedwig, ararat, prefaces, ministership,
# Nearest to universe: diagrams, copernican, constructible, abdallah, stars, wavefunction, civilization, handcuffs,
# Nearest to mainly: macron, dictum, crystals, idiomatic, protanomaly, admissions, indie, layouts,
# Nearest to know: don, submachine, dubliners, myself, px, credo, drafts, instructs,
# Nearest to nobel: prize, jens, winners, roald, electrodynamics, minimi, machiavellian, financier,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9636 0.3662 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9724 0.3590 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9257 0.3601 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9735 0.3609 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0011 0.3608 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9198 0.3605 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9562 0.3593 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9677 0.3609 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9534 0.3604 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9458 0.3588 sec/batch
# Nearest to most: in, twitch, third, basses, rulebooks, skaldic, confused, raster,
# Nearest to has: folger, the, poisonings, have, giraldus, applicants, avraham, exist,
# Nearest to american: bruin, connolly, alcan, rota, abgar, curran, gwen, uel,
# Nearest to its: vanadium, gaelic, caricatured, substituent, archtop, phonemic, exhaled, palisades,
# Nearest to called: slit, scottish, comico, vec, clockwork, subdivided, described, henry,
# Nearest to d: pasteur, bibliographer, pussy, falkirk, mri, ric, maclaine, eases,
# Nearest to his: he, precisely, topologies, accompany, resigned, tenure, took, had,
# Nearest to at: in, zachary, laughs, unfortunately, leben, clutter, integral, gre,
# Nearest to dr: picnic, odo, haemophilus, miho, millionaires, zy, roberts, nss,
# Nearest to proposed: explain, crumpled, jeppesen, maius, gpo, milligan, boardwalk, administratively,
# Nearest to alternative: cholesteric, correlatives, amsterdam, buchanan, ovary, bellori, realizations, riso,
# Nearest to account: instinctive, geoffrey, cartographic, perforce, prefaces, hedwig, uncompleted, ararat,
# Nearest to universe: diagrams, copernican, abdallah, stars, civilization, mika, handcuffs, constructible,
# Nearest to mainly: dictum, macron, admissions, idiomatic, indie, layouts, protanomaly, crystals,
# Nearest to know: don, submachine, px, dubliners, myself, credo, that, drafts,
# Nearest to nobel: prize, jens, winners, roald, electrodynamics, minimi, enders, machiavellian,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9880 0.3639 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9652 0.3610 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9572 0.3596 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9916 0.3602 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9963 0.3629 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9789 0.3612 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9488 0.3596 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9512 0.3624 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9324 0.3606 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9917 0.3617 sec/batch
# Nearest to most: in, third, twitch, rathdown, francophonie, raster, rulebooks, trench,
# Nearest to has: have, the, folger, poisonings, avraham, exist, giraldus, applicants,
# Nearest to american: bruin, connolly, alcan, abgar, uel, rota, gwen, dictatorship,
# Nearest to its: vanadium, gaelic, an, substituent, is, the, phonemic, blasted,
# Nearest to called: slit, scottish, subdivided, comico, described, vec, clockwork, turkey,
# Nearest to d: pasteur, bibliographer, mri, pussy, falkirk, eases, maclaine, corr,
# Nearest to his: he, precisely, topologies, resigned, aberdare, rewritten, accompany, tenure,
# Nearest to at: in, zachary, unfortunately, gre, integral, determinations, completion, attended,
# Nearest to dr: picnic, odo, miho, haemophilus, zy, endowment, civilised, hein,
# Nearest to proposed: explain, jeppesen, crumpled, maius, nkrumah, gpo, milligan, boardwalk,
# Nearest to alternative: cholesteric, correlatives, amsterdam, buchanan, bellori, buckland, realizations, riso,
# Nearest to account: geoffrey, cartographic, instinctive, perforce, hedwig, uncompleted, prefaces, ministership,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8282 0.3620 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8055 0.3612 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8018 0.3620 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8896 0.3603 sec/batch
# Nearest to most: in, and, third, the, dominant, incorporated, notably, there,
# Nearest to has: is, have, exist, the, of, s, that, folger,
# Nearest to american: bruin, vaudeville, fredericksburg, uel, oyly, connolly, bandleaders, english,
# Nearest to its: the, is, an, s, in, caricatured, phonemic, seventeen,
# Nearest to called: the, slit, as, described, toxin, a, also, comico,
# Nearest to d: pasteur, mri, ir, pussy, whitney, mondial, b, alimentarius,
# Nearest to his: he, him, topologies, knuckles, son, career, vanity, spent,
# Nearest to at: in, unfortunately, two, the, first, a, four, to,
# Nearest to dr: haemophilus, overheat, zy, assented, odo, miho, dis, teletype,
# Nearest to proposed: explain, speculation, gpo, jeppesen, milligan, familes, proponents, areas,
# Nearest to alternative: cholesteric, realizations, warrior, slang, excrement, buchanan, incident, ovary,
# Nearest to account: perforce, mortgage, geoffrey, cartographic, uncompleted, hedwig, particle, dsl,
# Nearest to universe: puzzles, mandy, multiverse, mika, barony, tre, unspeakable, robotic,
# Nearest to mainly: dictum, incapable, their, superscript, idiomatic, natively, macron, aravalli,
# Nearest to know: don, px, dubliners, that, absolutely, myself, we, gardening,
# Nearest to nobel: prize, winners, kees, jens, roald, laureate, machiavellian, electrodynamics,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8146 0.3653 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8227 0.3610 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8249 0.3611 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8243 0.3617 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8130 0.3591 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8588 0.3626 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8359 0.3593 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7963 0.3614 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8337 0.3620 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8383 0.3634 sec/batch
# Nearest to most: in, and, many, third, the, dominant, incorporated, notably,
# Nearest to has: is, exist, have, the, s, that, due, of,
# Nearest to american: bruin, vaudeville, uel, fredericksburg, bandleaders, reintroduced, curran, inductees,
# Nearest to its: the, is, s, an, in, a, phonemic, of,
# Nearest to called: the, slit, described, a, as, toxin, comico, jingwei,
# Nearest to d: mri, pasteur, pussy, ir, eases, dmc, alimentarius, whitney,
# Nearest to his: he, topologies, him, career, knuckles, son, resigned, reggio,
# Nearest to at: in, unfortunately, two, the, first, of, after, four,
# Nearest to dr: overheat, assented, odo, miho, zy, dis, roberts, haemophilus,
# Nearest to proposed: explain, speculation, gpo, milligan, netherlands, proponents, areas, citizen,
# Nearest to alternative: cholesteric, warrior, realizations, incident, slang, correlatives, buchanan, haystack,
# Nearest to account: perforce, mortgage, cartographic, geoffrey, hedwig, dsl, eurozone, uncompleted,
# Nearest to universe: mandy, puzzles, multiverse, barony, mika, cosmological, unspeakable, leinster,
# Nearest to mainly: dictum, incapable, their, compilers, natively, superscript, himalayan, idiomatic,
# Nearest to know: don, px, absolutely, dubliners, that, we, do, gardening,
# Nearest to nobel: prize, winners, kees, jens, roald, laureate, peace, electrodynamics,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8233 0.3683 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8253 0.3608 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8141 0.3638 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8316 0.3590 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8556 0.3614 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7804 0.3648 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9310 0.3620 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8788 0.3618 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9086 0.3593 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7822 0.3606 sec/batch
# Nearest to most: in, and, third, dominant, the, many, notably, incorporated,
# Nearest to has: is, have, exist, the, s, of, been, due,
# Nearest to american: bruin, uel, vaudeville, reintroduced, gwen, futures, inductees, fredericksburg,
# Nearest to its: the, is, s, in, of, an, a, as,
# Nearest to called: the, described, slit, toxin, a, as, comico, jingwei,
# Nearest to d: pasteur, mri, b, ir, falkirk, pussy, alimentarius, dmc,
# Nearest to his: he, knuckles, topologies, career, spent, him, reggio, cadet,
# Nearest to at: in, unfortunately, the, two, first, had, to, after,
# Nearest to dr: assented, overheat, miho, odo, zy, roberts, dis, physician,
# Nearest to proposed: explain, speculation, gpo, milligan, citizen, netherlands, proponents, areas,
# Nearest to alternative: cholesteric, warrior, realizations, incident, buchanan, slang, dearborn, amsterdam,
# Nearest to account: perforce, hedwig, mortgage, geoffrey, dsl, cartographic, frederik, prefaces,
# Nearest to universe: puzzles, mandy, multiverse, barony, mika, leinster, cosmological, robotic,
# Nearest to mainly: dictum, incapable, their, himalayan, superscript, lipids, natively, exploiting,
# Nearest to know: don, px, dubliners, absolutely, we, that, do, myself,
# Nearest to nobel: prize, winners, kees, peace, jens, roald, laureate, machiavellian,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7458 0.3662 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8425 0.3622 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7479 0.3612 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8280 0.3594 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8072 0.3605 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8046 0.3599 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8721 0.1740 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7818 0.3608 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8083 0.3616 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7864 0.3629 sec/batch
# Nearest to most: in, and, dominant, the, many, third, incorporated, notably,
# Nearest to has: is, have, exist, s, been, the, of, due,
# Nearest to american: bruin, vaudeville, uel, reintroduced, gwen, curran, bandleaders, futures,
# Nearest to its: the, is, s, an, in, gaelic, itself, a,
# Nearest to called: the, described, slit, as, toxin, a, microorganism, etymology,
# Nearest to d: b, pasteur, mri, pussy, ir, dmc, falkirk, mondial,
# Nearest to his: he, was, to, him, son, had, topologies, aberdare,
# Nearest to at: in, the, unfortunately, to, had, after, of, a,
# Nearest to dr: miho, assented, physician, overheat, zy, roberts, teletype, berthold,
# Nearest to proposed: explain, speculation, gpo, milligan, netherlands, citizen, concubines, familes,
# Nearest to alternative: cholesteric, slang, warrior, realizations, dearborn, correlatives, excrement, amsterdam,
# Nearest to account: perforce, hedwig, geoffrey, mortgage, dsl, cartographic, frederik, uncompleted,
# Nearest to universe: multiverse, puzzles, mandy, god, cosmological, barony, leinster, mika,
# Nearest to mainly: dictum, incapable, their, himalayan, compilers, involved, natively, lipids,
# Nearest to know: don, dubliners, px, absolutely, that, we, do, tisdall,
# Nearest to nobel: prize, winners, kees, laureate, jens, peace, roald, electrodynamics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8060 0.3645 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7804 0.3604 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7781 0.3623 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7411 0.3594 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8094 0.3624 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7770 0.3695 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8425 0.3608 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7124 0.3630 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7880 0.3613 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7818 0.3612 sec/batch
# Nearest to most: in, and, the, dominant, many, by, notably, such,
# Nearest to has: is, have, of, exist, the, s, that, been,
# Nearest to american: bruin, curran, gwen, vaudeville, futures, reintroduced, fredericksburg, uel,
# Nearest to its: the, is, in, an, s, a, of, to,
# Nearest to called: the, described, as, of, a, slit, toxin, microorganism,
# Nearest to d: mri, ir, pussy, dmc, alimentarius, pasteur, ncs, catches,
# Nearest to his: he, him, spent, son, career, topologies, knuckles, vanity,
# Nearest to at: in, unfortunately, two, a, to, four, the, least,
# Nearest to dr: haemophilus, miho, assented, berthold, physician, roberts, zy, overheat,
# Nearest to proposed: explain, speculation, gpo, milligan, proponents, supergravity, crumpled, familes,
# Nearest to alternative: cholesteric, slang, warrior, realizations, amsterdam, dearborn, buchanan, incident,
# Nearest to account: perforce, hedwig, frederik, mortgage, geoffrey, cartographic, unknown, uncompleted,
# Nearest to universe: cosmological, multiverse, puzzles, tre, mandy, leinster, barony, robotic,
# Nearest to mainly: incapable, dictum, their, compilers, himalayan, involved, lipids, natively,
# Nearest to know: don, px, dubliners, absolutely, that, we, do, gardening,
# Nearest to nobel: prize, winners, kees, laureate, jens, peace, roald, electrodynamics,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7186 0.3652 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7828 0.3625 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8435 0.3582 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7971 0.3613 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8061 0.3610 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8375 0.3580 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8259 0.3614 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7961 0.3594 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8073 0.3638 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8067 0.3630 sec/batch
# Nearest to most: in, and, notably, many, dominant, the, for, incorporated,
# Nearest to has: is, have, the, exist, of, s, that, been,
# Nearest to american: bruin, gwen, futures, vaudeville, reintroduced, uel, bandleaders, fredericksburg,
# Nearest to its: the, is, a, s, in, an, of, which,
# Nearest to called: the, described, slit, a, of, as, is, also,
# Nearest to d: mri, pussy, ir, pasteur, alimentarius, dmc, b, catches,
# Nearest to his: he, him, son, topologies, career, spent, reggio, aberdare,
# Nearest to at: in, unfortunately, a, two, first, the, lachaise, to,
# Nearest to dr: miho, haemophilus, teletype, roberts, physician, berthold, assented, zy,
# Nearest to proposed: explain, speculation, gpo, gao, milligan, proponents, netherlands, stuck,
# Nearest to alternative: cholesteric, warrior, slang, buchanan, realizations, correlatives, haystack, amsterdam,
# Nearest to account: perforce, mortgage, hedwig, frederik, cartographic, uncompleted, dsl, takes,
# Nearest to universe: mandy, cosmological, multiverse, puzzles, slug, barony, leinster, wiles,
# Nearest to mainly: incapable, their, dictum, natively, himalayan, kiswahili, compilers, macron,
# Nearest to know: don, px, absolutely, dubliners, do, that, we, tisdall,
# Nearest to nobel: prize, winners, kees, laureate, peace, jens, roald, electrodynamics,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8512 0.3657 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7754 0.3589 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8162 0.3602 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8133 0.3605 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8173 0.3601 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7928 0.3621 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8120 0.3616 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7997 0.3607 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7715 0.3626 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8022 0.3595 sec/batch
# Nearest to most: in, and, the, there, many, notably, by, incorporated,
# Nearest to has: is, the, have, exist, of, s, that, been,
# Nearest to american: bruin, reintroduced, futures, gwen, vaudeville, bandleaders, uel, curran,
# Nearest to its: the, is, a, s, in, an, to, of,
# Nearest to called: the, described, as, of, a, slit, is, also,
# Nearest to d: dmc, mri, pussy, alimentarius, pasteur, ir, ncs, affording,
# Nearest to his: he, him, son, aberdare, spent, topologies, himself, cadet,
# Nearest to at: in, unfortunately, two, the, a, zero, four, after,
# Nearest to dr: miho, zy, roberts, haemophilus, berthold, assented, teletype, physician,
# Nearest to proposed: explain, speculation, gpo, gao, milligan, netherlands, beagle, secretive,
# Nearest to alternative: cholesteric, warrior, slang, buchanan, dearborn, amsterdam, existed, haystack,
# Nearest to account: perforce, mortgage, hedwig, frederik, dsl, cartographic, uncompleted, particle,
# Nearest to universe: mandy, cosmological, multiverse, puzzles, mika, barony, slug, leinster,
# Nearest to mainly: incapable, their, involved, dictum, himalayan, natively, exploiting, for,
# Nearest to know: don, px, absolutely, dubliners, we, do, that, submachine,
# Nearest to nobel: prize, winners, kees, peace, jens, laureate, roald, electrodynamics,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8196 0.3674 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7813 0.3630 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9002 0.3621 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8701 0.3624 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8578 0.3585 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8309 0.3619 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7326 0.3594 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7889 0.3582 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6892 0.3617 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8528 0.3611 sec/batch
# Nearest to most: in, dominant, notably, and, the, by, many, third,
# Nearest to has: is, the, exist, have, of, s, but, due,
# Nearest to american: reintroduced, bruin, gwen, eight, uel, english, vaudeville, bandleaders,
# Nearest to its: the, is, s, in, an, a, of, which,
# Nearest to called: the, described, a, as, of, slit, also, is,
# Nearest to d: b, pasteur, falkirk, whitney, arbuthnot, dmc, american, corr,
# Nearest to his: he, him, topologies, career, cadet, himself, son, vanity,
# Nearest to at: in, unfortunately, to, a, first, attended, degrees, minardi,
# Nearest to dr: miho, berthold, haemophilus, zy, roberts, assented, teletype, emeritus,
# Nearest to proposed: explain, speculation, gao, gpo, milligan, ellice, secretive, netherlands,
# Nearest to alternative: cholesteric, warrior, slang, buchanan, amsterdam, excrement, dearborn, haystack,
# Nearest to account: perforce, mortgage, frederik, ims, cartographic, hedwig, takes, dsl,
# Nearest to universe: mandy, multiverse, cosmological, leinster, puzzles, mika, wiles, slug,
# Nearest to mainly: incapable, dictum, himalayan, involved, their, natively, kiswahili, initialized,
# Nearest to know: don, px, absolutely, dubliners, that, we, do, tisdall,
# Nearest to nobel: prize, winners, peace, kees, laureate, jens, roald, recipient,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7968 0.3634 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7910 0.3634 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
